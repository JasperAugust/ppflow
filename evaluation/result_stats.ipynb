# %%
import os
import pandas as pd

results_dir = '/gpfs/helios/home/tootsi/homing/ppflow/results-nanomed/ppflow/optimize_ppflow_233k2510'

lower_energy_counts = {}

for folder in os.listdir(results_dir):
    folder_path = os.path.join(results_dir, folder)
    if not os.path.isdir(folder_path):
        continue
    
    csv_file = os.path.join(folder_path, 'peptide_metrics.csv')
    if not os.path.exists(csv_file):
        continue
    
    df = pd.read_csv(csv_file)
    
    # Assuming the reference peptide is named 'reference.pdb'
    reference_energy = df[df['pdb_name'] == 'reference.pdb']['dg'].values[0]
    
    lower_energy_count = (df['dg'] < reference_energy).sum()
    total_peptides = len(df) - 1  # Subtract 1 to exclude the reference peptide
    
    lower_energy_counts[folder] = {
        'count': lower_energy_count,
        'total': total_peptides,
        'percentage': (lower_energy_count / total_peptides) * 100 if total_peptides > 0 else 0
    }

# Print results
for folder, stats in lower_energy_counts.items():
    print(f"{folder}:")
    print(f"  Peptides with lower energy: {stats['count']} out of {stats['total']} ({stats['percentage']:.2f}%)")
    print()

# Calculate overall statistics
total_lower_energy = sum(stats['count'] for stats in lower_energy_counts.values())
total_peptides = sum(stats['total'] for stats in lower_energy_counts.values())
overall_percentage = (total_lower_energy / total_peptides) * 100 if total_peptides > 0 else 0

print("Overall statistics:")
print(f"Total peptides with lower energy: {total_lower_energy} out of {total_peptides} ({overall_percentage:.2f}%)")


# Print receptors with lower energy peptides
print("\nReceptors with lower energy peptides:")
for folder, stats in lower_energy_counts.items():
    if stats['count'] > 0:
        receptor = folder.split('_')[1]  # Extract receptor name from folder
        print(f"{receptor}: {stats['count']} lower energy peptides")
# Out:
# 0110_2ht9_2024_10_24__17_02_37:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0060_3c3r_2024_10_24__16_54_00:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0117_1t08_2024_10_24__17_03_43:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0032_2fts_2024_10_24__16_49_18:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0130_3w1b_2024_10_24__17_05_54:
#   Peptides with lower energy: 4 out of 20 (20.00%)
#
# 0092_4dcb_2024_10_24__16_59_34:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0050_2dyp_2024_10_24__16_52_24:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0036_3ll8_2024_10_24__16_50_05:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0055_1ntv_2024_10_24__16_53_15:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0053_1x2r_2024_10_24__16_52_52:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0128_2p1t_2024_10_24__17_05_36:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0026_3u9q_2024_10_24__16_48_10:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0040_2bba_2024_10_24__16_50_48:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0109_2o4j_2024_10_24__17_02_25:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0000_2qbx_2024_10_24__16_43_49:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0010_1oai_2024_10_24__16_45_36:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0078_2puy_2024_10_24__16_57_20:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0087_3awr_2024_10_24__16_58_52:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0056_2qos_2024_10_24__16_53_26:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0096_2drk_2024_10_24__17_00_14:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0006_2ffu_2024_10_24__16_44_56:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0022_3tjv_2024_10_24__16_47_23:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0038_3so6_2024_10_24__16_50_25:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0037_3fdo_2024_10_24__16_50_17:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0012_4f14_2024_10_24__16_45_45:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0001_1hc9_2024_10_24__16_44_02:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0027_2cch_2024_10_24__16_48_21:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0048_1mfg_2024_10_24__16_52_06:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0015_2pux_2024_10_24__16_46_13:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0021_3kuj_2024_10_24__16_47_16:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0131_1nq7_2024_10_24__17_06_05:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0101_3p8f_2024_10_24__17_00_51:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0116_2xrw_2024_10_24__17_03_31:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0004_1qkz_2024_10_24__16_44_32:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0080_4h4f_2024_10_24__16_57_37:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0084_2vkn_2024_10_24__16_58_23:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0024_2fvj_2024_10_24__16_47_46:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0043_1t4f_2024_10_24__16_51_18:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0072_2qse_2024_10_24__16_56_17:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0085_3h1z_2024_10_24__16_58_28:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0100_2w2u_2024_10_24__17_00_45:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0042_3vtc_2024_10_24__16_51_07:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0046_1ywo_2024_10_24__16_51_50:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0119_2whx_2024_10_24__17_04_00:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0019_2vwf_2024_10_24__16_46_59:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0127_3kmr_2024_10_24__17_05_24:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0089_2aq9_2024_10_24__16_59_10:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0082_2r9q_2024_10_24__16_58_00:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0097_3ery_2024_10_24__17_00_19:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0062_4gq6_2024_10_24__16_54_23:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0009_3zqh_2024_10_24__16_45_24:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0123_3sfj_2024_10_24__17_04_40:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0093_1xoc_2024_10_24__16_59_46:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0081_3ayu_2024_10_24__16_57_48:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0121_2xu7_2024_10_24__17_04_24:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0061_1rst_2024_10_24__16_54_12:
#   Peptides with lower energy: 1 out of 20 (5.00%)
#
# 0067_1cjr_2024_10_24__16_55_21:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0044_2fff_2024_10_24__16_51_26:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0090_2ho2_2024_10_24__16_59_22:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0108_2p0w_2024_10_24__17_02_13:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0125_3rqg_2024_10_24__17_05_01:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0122_2d0n_2024_10_24__17_04_36:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0007_3asl_2024_10_24__16_45_07:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0098_1d4t_2024_10_24__17_00_31:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0099_4iim_2024_10_24__17_00_40:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0020_1nx1_2024_10_24__16_47_04:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0124_4htp_2024_10_24__17_04_49:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0008_3tzy_2024_10_24__16_45_13:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0025_3llz_2024_10_24__16_47_58:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0034_4gyw_2024_10_24__16_49_42:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0028_2zjd_2024_10_24__16_48_33:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0041_3kus_2024_10_24__16_51_00:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0106_1h6w_2024_10_24__17_01_50:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0095_3up3_2024_10_24__17_00_02:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0047_2v8y_2024_10_24__16_51_54:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0076_4k0u_2024_10_24__16_56_59:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0059_3rm1_2024_10_24__16_53_52:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0104_2b9h_2024_10_24__17_01_27:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0031_2a25_2024_10_24__16_49_07:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0103_2o02_2024_10_24__17_01_15:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0064_4f1z_2024_10_24__16_54_46:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0033_1pzl_2024_10_24__16_49_30:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0075_4e34_2024_10_24__16_56_52:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0071_2ce8_2024_10_24__16_56_05:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0102_1k5n_2024_10_24__17_01_03:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0077_4b4n_2024_10_24__16_57_08:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0045_2a3i_2024_10_24__16_51_38:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0011_2oei_2024_10_24__16_45_41:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0003_1jbu_2024_10_24__16_44_20:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0030_3g2s_2024_10_24__16_48_55:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0052_1ssh_2024_10_24__16_52_47:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0065_1rxz_2024_10_24__16_54_58:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0066_4ery_2024_10_24__16_55_09:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0094_1cka_2024_10_24__16_59_57:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0013_1tfc_2024_10_24__16_45_50:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0017_1sfi_2024_10_24__16_46_35:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0074_2fmf_2024_10_24__16_56_40:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0115_4eik_2024_10_24__17_03_26:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0016_3d32_2024_10_24__16_46_25:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0069_3olf_2024_10_24__16_55_42:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0111_3p72_2024_10_24__17_02_46:
#   Peptides with lower energy: 1 out of 20 (5.00%)
#
# 0057_1oj5_2024_10_24__16_53_38:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0086_1ymt_2024_10_24__16_58_41:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0126_2p1o_2024_10_24__17_05_12:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0129_3i5r_2024_10_24__17_05_47:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0054_4j8s_2024_10_24__16_53_03:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0114_1uj0_2024_10_24__17_03_21:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0073_3l0e_2024_10_24__16_56_28:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0035_2vr3_2024_10_24__16_49_53:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0083_1ow6_2024_10_24__16_58_11:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0070_3v2x_2024_10_24__16_55_54:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0005_1t7r_2024_10_24__16_44_44:
#   Peptides with lower energy: 9 out of 20 (45.00%)
#
# 0002_3bfq_2024_10_24__16_44_08:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0068_1yuc_2024_10_24__16_55_30:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0039_2fka_2024_10_24__16_50_37:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0105_2r7g_2024_10_24__17_01_38:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0079_3gyt_2024_10_24__16_57_25:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0051_4hom_2024_10_24__16_52_35:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0112_1nln_2024_10_24__17_02_57:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0120_1u00_2024_10_24__17_04_13:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0113_3qis_2024_10_24__17_03_09:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0091_2peh_2024_10_24__16_59_25:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0049_1ou8_2024_10_24__16_52_14:
#   Peptides with lower energy: 1 out of 20 (5.00%)
#
# 0107_3obq_2024_10_24__17_02_01:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0088_1cvu_2024_10_24__16_58_58:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0023_3ptl_2024_10_24__16_47_35:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0063_3ivv_2024_10_24__16_54_34:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0058_2xvc_2024_10_24__16_53_47:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0132_3ds4_2024_10_24__17_06_17:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0118_2o9v_2024_10_24__17_03_55:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0029_4gxl_2024_10_24__16_48_44:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0018_1eg4_2024_10_24__16_46_47:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# 0014_2p54_2024_10_24__16_46_01:
#   Peptides with lower energy: 0 out of 20 (0.00%)
#
# Overall statistics:
# Total peptides with lower energy: 16 out of 2660 (0.60%)
#
# Receptors with lower energy peptides:
# 3w1b: 4 lower energy peptides
# 1rst: 1 lower energy peptides
# 3p72: 1 lower energy peptides
# 1t7r: 9 lower energy peptides
# 1ou8: 1 lower energy peptides
